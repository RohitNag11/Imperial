# %% [markdown]
# # Statistics Exercise Sheet 1

# %%
import sys
# setting path
sys.path.append('..')

from helperlib import (
    statsFunctions as hstats
) 

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
emissions = np.array([15, 25, 22, 31, 25, 19, 8, 24, 44, 30, 34, 12, 7, 33, 19, 20, 19, 42, 38, 27])
mins = np.arange(1, len(emissions) + 1, 1)

# %% [markdown]
# ## 1. Construct a suitable histogram plot for the Geiger counter data.

# %%
sns.displot(x=emissions, kde=True, bins=6, stat="density")

# %% [markdown]
# ## 3.2. Determine the sample mean, the sample variance, the median and the mode of the Geiger counter data.

# %%
hstats.summarise_data(pd.Series(emissions))
# Out:
# Data summary:
#  location:
#   {'mean': 24.7, 'median': 24.5, 'lowerq': 19.0, 'upperq': 31.5, 'min': 7, 'max': 44}
#  dispersion:
#   {'range': 37, 'iqr': 12.5, 'var': 108.01052631578946, 'std': 10.392811280678076}
#  skewness:
#   {'skew': 0.1387588616488745, 'kurtosis': -0.5128730691727879}
